# %%
# %cat can/can.yaml
# Out:
# # train and val data as 1) directory: path/images/, 2) file: path/images.txt, or 3) list: [path1/images/, path2/images/]
# train: can/train.txt
# val: can/val.txt
# test: can/test.txt
#
# # number of classes
# nc: 1
#
# # class names
# names: ['can']

# %%
# Check the length of images
from glob import glob

# Need to change the extension to 'jpg'
img_list = glob('can/images/*.jpg')
print(len(img_list))
# Out:
# 1686

# %%
# Split dataset to train/valid/test
from sklearn.model_selection import train_test_split

train_img_list, temp_img_list = train_test_split(img_list, test_size=0.3, random_state=11)
val_img_list, test_img_list = train_test_split(temp_img_list, test_size=0.3, random_state=11)

print(len(train_img_list), len(val_img_list), len(test_img_list))

# Create reference files
with open('can/train.txt', 'w') as f:
    f.write('\n'.join(train_img_list) + '\n')

with open('can/val.txt', 'w') as f:
    f.write('\n'.join(val_img_list) + '\n')

with open('can/test.txt', 'w') as f:
    f.write('\n'.join(test_img_list) + '\n')
# Out:
# 1180 354 152

# %%
# !python train.py --batch 32 --data can/can.yaml --weights weights/yolov5m.pt --epochs 300 --cache
# Out:
# Your branch is behind 'origin/master' by 73 commits, and can be fast-forwarded.
#   (use "git pull" to update your local branch)
#
# Using torch 1.7.0 CUDA:0 (Tesla V100-SXM2-16GB, 16160MB)
#
# Namespace(adam=False, batch_size=32, bucket='', cache_images=True, cfg='', data='can/can.yaml', device='', epochs=300, evolve=False, global_rank=-1, hyp='data/hyp.scratch.yaml', image_weights=False, img_size=[640, 640], local_rank=-1, log_imgs=10, logdir='runs/train', multi_scale=False, name='', noautoanchor=False, nosave=False, notest=False, rect=False, resume=False, single_cls=False, sync_bn=False, total_batch_size=32, weights='weights/yolov5m.pt', workers=8, world_size=1)
# Start Tensorboard with "tensorboard --logdir runs/train", view at http://localhost:6006/
# ...

# %%
# Test
# !python test.py --batch-size 16 --data can/can.yaml --weights 1205.pt --save-txt --save-conf --task test
# Out:
# Namespace(augment=False, batch_size=16, conf_thres=0.001, data='can/can.yaml', device='', img_size=640, iou_thres=0.65, name='', save_conf=True, save_dir='runs/test', save_json=False, save_txt=True, single_cls=False, task='test', verbose=False, weights=['1205.pt'])
# Using torch 1.7.0 CUDA:0 (Tesla V100-SXM2-16GB, 16160MB)
#
# Fusing layers...
# Model Summary: 188 layers, 2.14686e+07 parameters, 0 gradients
# Scanning images: 100%|███████████████████████| 152/152 [00:00<00:00, 471.99it/s]
# Scanning labels can/labels.cache (138 found, 0 missing, 14 empty, 0 duplicate, for 152 images): 152it [00:00, 14147.31it/s]
#                Class      Images     Targets           P           R      mAP@.5
#                  all         152         484       0.825       0.966       0.982       0.918
# Speed: 3.2/1.3/4.5 ms inference/NMS/total per 640x640 image at batch-size 16
# Results saved to runs/test/exp2
# Internal process exited
