# %%
# Test
# !python detect.py --img-size 512 --weights forServiceTest/weights/yolov5_1128.pt --save-txt --source testImages/
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', img_size=512, iou_thres=0.45, name='', save_conf=False, save_dir='runs/detect', save_txt=True, source='testImages/', update=False, view_img=False, weights=['forServiceTest/weights/yolov5_1128.pt'])
# Using torch 1.7.0 CUDA:0 (Tesla K80, 11441MB)
#
# Fusing layers...
# Model Summary: 188 layers, 2.14686e+07 parameters, 0 gradients
# image 1/413 /home/K/Dev/yolov5/testImages/1003937830896513672.jpg: 512x512 1 cans, Done. (0.062s)
# image 2/413 /home/K/Dev/yolov5/testImages/1009491628595141870.jpg: 512x512 Done. (0.061s)
# image 3/413 /home/K/Dev/yolov5/testImages/1015743965305385189.jpg: 512x512 3 cans, Done. (0.057s)
# image 4/413 /home/K/Dev/yolov5/testImages/1015942126588974006.jpg: 512x512 2 cans, Done. (0.057s)
# image 5/413 /home/K/Dev/yolov5/testImages/1015999808286513781.jpg: 512x512 3 cans, Done. (0.053s)
# ...

# %%
from torchvision import models
import torch.nn as nn

modelc = models.resnet18(pretrained=True)
num_ftrs = modelc.fc.in_features
modelc.fc = nn.Linear(num_ftrs, 48) # Generalized 할것
modelc.load_state_dict(torch.load('forServiceTest/weights/resnet18_48class.pt'))
modelc
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
import rexnetv1

modelc = rexnetv1.ReXNetV1(width_mult=1.0, classes=48).cuda()
modelc.load_state_dict(torch.load('forServiceTest/weights/RexNet_48class_1205.pt'))
modelc
# Out:
# ReXNetV1(
#   (features): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): Swish()
#     (3): LinearBottleneck(
#       (out): Sequential(
#         (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU6()
#         (3): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (4): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (4): LinearBottleneck(
#       (out): Sequential(
#         (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): Swish()
# ...
