# %%
# %cat data/can.yaml
# Out:
# cat: data/can.yaml: No such file or directory

# %%
from glob import glob

img_list = glob('can/images/*.jpg')
print(len(img_list))
# Out:
# 804

# %%
from sklearn.model_selection import train_test_split

train_img_list, val_img_list = train_test_split(img_list, test_size=0.2, random_state=2000)
print(len(train_img_list), len(val_img_list))
# Out:
# 643 161

# %%
train_file = 'can/train.txt'
val_file = 'can/val.txt'

with open(train_file, 'w') as f:
    f.write('\n'.join(train_img_list) + '\n')

with open(val_file, 'w') as f:
    f.write('\n'.join(val_img_list) + '\n')

# %%
# !MKL_THREADING_LAYER=GNU python3 train.py --batch-size 16 --img 416 --data can/can.data --cache --epochs 300
# Out:
# Apex recommended for faster mixed precision training: https://github.com/NVIDIA/apex
# Your branch is behind 'origin/master' by 5 commits, and can be fast-forwarded.
#   (use "git pull" to update your local branch)
#
# Namespace(adam=False, batch_size=16, bucket='', cache_images=True, cfg='cfg/yolov3-spp.cfg', data='can/can.data', device='', epochs=300, evolve=False, freeze_layers=False, img_size=[416], multi_scale=False, name='', nosave=False, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla K80', total_memory=11441MB)
#
# Start Tensorboard with "tensorboard --logdir=runs", view at http://localhost:6006/
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# Optimizer groups: 76 .bias, 76 Conv2d.weight, 73 other
# Caching labels can/train.txt (618 found, 0 missing, 25 empty, 0 duplicate, for 6
# ...

# %%
from utils.utils import *;
strip_optimizer('weights/best.pt')
# Out:
# Optimizer stripped from weights/best.pt

# %%
# !MKL_THREADING_LAYER=GNU python detect.py --source test/ --save-txt
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-spp.cfg', classes=None, conf_thres=0.3, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='can/can.names', output='output', save_txt=True, source='test/', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla K80', total_memory=11441MB)
#
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# 2
# image 1/444 test/1.26190433596340561b.jpg: 384x512 33 cans, Done. (0.089s)
# image 2/444 test/101.img.jpg: 384x512 3 cans, Done. (0.083s)
# image 3/444 test/120.15874_6354_3528.jpg: 384x512 30 cans, Done. (0.083s)
# image 4/444 test/121.img.jpg: 448x512 18 cans, Done. (0.097s)
# image 5/444 test/129.109033_107394_2137.jpeg: 384x512 15 cans, Done. (0.075s)
# image 6/444 test/129.624bc2075c962f.jpg: 512x320 1 cans, Done. (0.065s)
# image 7/444 test/1303019659100365205.jpg: 384x512 5 cans, Done. (0.074s)
# ...
